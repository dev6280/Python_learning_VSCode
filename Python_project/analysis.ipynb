# %%
import pandas as pd
df=pd.read_csv("Orders_data.csv")
df.head(2)
# Out:
#    Row ID        Order ID  Order Date  Year     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2020  2020  Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2020  2020  Second Class    CG-12520
#
#     Segment        Country       City     State  Postal Code Region  \
# 0  Consumer  United States  Henderson  Kentucky        42420  South
# 1  Consumer  United States  Henderson  Kentucky        42420  South
#
#         Product ID  Sales Amount  Quantity  Discount    Profit SalesPerson
# 0  FUR-BO-10001798        261.96         2       0.0   41.9136      SP_202
# 1  FUR-CH-10000454        731.94         3       0.0  219.5820      SP_430

# %%
#df.query('City == "Henderson" and Year == 2021')
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Year', 'Ship Mode', 'Customer ID',
#        'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region',
#        'Product ID', 'Sales Amount', 'Quantity', 'Discount', 'Profit',
#        'SalesPerson'],
#       dtype='object')

# %%
df["Ship Mode"].memory_usage(deep =True)
# Out:
# 10539

# %%
df["Ship Mode"] = df["Ship Mode"].astype("category")

# %%
df1= pd.DataFrame({
    "Name": ["A", "B", "C"],
    "Colors": [["Red", "Yellow"], ["Blue"], ["Green", "Purple", "Black"]]
    })
df1
# Out:
#   Name                  Colors
# 0    A           [Red, Yellow]
# 1    B                  [Blue]
# 2    C  [Green, Purple, Black]

# %%
df1.explode("Colors")
# Out:
#   Name  Colors
# 0    A     Red
# 0    A  Yellow
# 1    B    Blue
# 2    C   Green
# 2    C  Purple
# 2    C   Black

# %%
df1["Colors"].str.split(",")
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# Name: Colors, dtype: object

# %%
df1["Colors"].apply(
    lambda x: x if isinstance(x, list) or pd.isna(x) else x.split(", "))
# Out:
# 0             [Red, Yellow]
# 1                    [Blue]
# 2    [Green, Purple, Black]
# Name: Colors, dtype: object

# %%
# Out:
# 0             Henderson
# 1             Henderson
# 2           Los Angeles
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: category
# Categories (531, object): ['Aberdeen', 'Abilene', 'Akron', 'Albuquerque', ..., 'Yonkers', 'York', 'Yucaipa', 'Yuma']

# %%
df.head(4)
# Out:
#    Row ID        Order ID  Order Date  Year       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2020  2020    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2020  2020    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2020  2020    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2019  2019  Standard Class    SO-20335
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky        42420  South
# 1   Consumer  United States        Henderson    Kentucky        42420  South
# 2  Corporate  United States      Los Angeles  California        90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID  Sales Amount  Quantity  Discount    Profit SalesPerson
# 0  FUR-BO-10001798      261.9600         2      0.00   41.9136      SP_202
# ...

# %%
df[0:3]
# Out:
#    Row ID        Order ID  Order Date  Year     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2020  2020  Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2020  2020  Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2020  2020  Second Class    DV-13045
#
#      Segment        Country         City       State  Postal Code Region  \
# 0   Consumer  United States    Henderson    Kentucky        42420  South
# 1   Consumer  United States    Henderson    Kentucky        42420  South
# 2  Corporate  United States  Los Angeles  California        90036   West
#
#         Product ID  Sales Amount  Quantity  Discount    Profit SalesPerson
# 0  FUR-BO-10001798        261.96         2       0.0   41.9136      SP_202
# 1  FUR-CH-10000454        731.94         3       0.0  219.5820      SP_430
# 2  OFF-LA-10000240         14.62         2       0.0    6.8714      SP_344

# %%
df.iloc[[1,4,5],[9]]
# Out:
#         State
# 1    Kentucky
# 4     Florida
# 5  California

# %%
d = [1,3,5,9,6]
c = [2,4,8,7]
i = 0
j = 0
arr = []
n = 0
while i < len(d):
    while j < len(c):
        if d[i] < d[j]:
            arr[n] = d[i]
            i += 1
            print(arr)
        else:
            arr[n] = c[j]
            j += 1
    n+= 1
arr
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 14
#      12         print(arr)
#      13     else:
# ---> 14         arr[n] = c[j]
#      15         j += 1
#      16 n+= 1
#
# IndexError: list assignment index out of range
